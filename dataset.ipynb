# %%
import pandas as pd

# %%
df1 = pd.read_csv("Datasets/2026.csv")
df2 = pd.read_csv("Datasets/2025.csv")
df3 = pd.read_csv("Datasets/2024.csv")
df4 = pd.read_csv("Datasets/2023.csv")
df5 = pd.read_csv("Datasets/2022.csv")
df6 = pd.read_csv("Datasets/2021.csv")
df7 = pd.read_csv("Datasets/2020.csv")
df8 = pd.read_csv("Datasets/2019.csv")
df9 = pd.read_csv("Datasets/2018.csv")
df10 = pd.read_csv("Datasets/2017.csv")
df11 = pd.read_csv("Datasets/2016.csv")
df12 = pd.read_csv("Datasets/2015.csv")

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12], ignore_index=True)

# %%
df.to_csv("Earthquake.csv", index=False)

# %%
data = pd.read_csv("Earthquake.csv")

# %%
data.head()
# Out:
#                        time  latitude  longitude    depth   mag magType   nst  \
# 0  2026-03-31T23:29:47.277Z  -22.1796  -179.6895  562.749  4.50      mb  23.0
# 1  2026-03-31T22:40:43.430Z   19.2428   -64.8535   23.000  3.51      md  18.0
# 2  2026-03-31T21:56:33.682Z  -12.7320   169.2141  642.156  5.10      mb  67.0
# 3  2026-03-31T21:38:31.620Z   19.6020   -63.7088   37.000  3.87      md  15.0
# 4  2026-03-31T21:32:37.680Z   19.2313   -64.9078    7.000  3.60      ml  21.0
#
#      gap    dmin   rms  ...                   updated  \
# 0  111.0  4.8960  0.85  ...  2026-04-01T00:56:47.040Z
# 1  245.0  0.8605  0.38  ...  2026-04-01T04:37:56.662Z
# 2   44.0  3.3300  0.55  ...  2026-03-31T22:10:36.040Z
# 3  319.0  1.4955  0.39  ...  2026-04-01T01:39:05.389Z
# 4  255.0  0.8660  0.67  ...  2026-04-01T01:26:13.727Z
#
#                                                place        type  \
# 0                          south of the Fiji Islands  earthquake
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186780 entries, 0 to 186779
# Data columns (total 22 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   time             186780 non-null  object
#  1   latitude         186780 non-null  float64
#  2   longitude        186780 non-null  float64
#  3   depth            186780 non-null  float64
#  4   mag              186780 non-null  float64
#  5   magType          186780 non-null  object
#  6   nst              71397 non-null   float64
#  7   gap              182249 non-null  float64
#  8   dmin             181534 non-null  float64
#  9   rms              186652 non-null  float64
#  10  net              186780 non-null  object
#  11  id               186780 non-null  object
#  12  updated          186780 non-null  object
#  13  place            186780 non-null  object
#  14  type             186780 non-null  object
#  15  horizontalError  183614 non-null  float64
# ...

# %%
df["type"].value_counts()
# Out:
# type
# earthquake                    186468
# mining explosion                 214
# volcanic eruption                 73
# experimental explosion             8
# mine collapse                      5
# landslide                          4
# nuclear explosion                  3
# other event                        2
# explosion                          1
# induced or triggered event         1
# collapse                           1
# Name: count, dtype: int64
